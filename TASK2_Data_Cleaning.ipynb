# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanidaragani12-stack/SQTS-Data-Analytics-Internship/blob/main/TASK2_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb018ed6-dde1-469d-b8e1-8c38fdd1fe7b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb018ed6-dde1-469d-b8e1-8c38fdd1fe7b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel("retail_store_sales.csv.xlsx")

# %%
df.head()
# Out:
#   Transaction ID       Category          Item  Price Per Unit  Quantity  \
# 0    TXN_6867343     Patisserie   Item_10_PAT            18.5      10.0
# 1    TXN_3731986  Milk Products  Item_17_MILK            29.0       9.0
# 2    TXN_9303719       Butchers   Item_12_BUT            21.5       2.0
# 3    TXN_9458126      Beverages   Item_16_BEV            27.5       9.0
# 4    TXN_4575373           Food   Item_6_FOOD            12.5       7.0
#
#    Total Spent  Payment Method Transaction Date  Discount Applied
# 0        185.0  Digital Wallet       2024-04-08               1.0
# 1        261.0  Digital Wallet       2023-07-23               1.0
# 2         43.0     Credit Card       2022-10-05               0.0
# 3        247.5     Credit Card       2022-05-07               NaN
# 4         87.5  Digital Wallet       2022-10-02               0.0

# %%
df["Transaction ID"]
# Out:
# 0        TXN_6867343
# 1        TXN_3731986
# 2        TXN_9303719
# 3        TXN_9458126
# 4        TXN_4575373
#             ...
# 12570    TXN_9347481
# 12571    TXN_4009414
# 12572    TXN_5306010
# 12573    TXN_5167298
# 12574    TXN_2407494
# Name: Transaction ID, Length: 12575, dtype: object

# %%
df["Transaction ID"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Category"]
# Out:
# 0           Patisserie
# 1        Milk Products
# 2             Butchers
# 3            Beverages
# 4                 Food
#              ...
# 12570       Patisserie
# 12571        Beverages
# 12572         Butchers
# 12573        Furniture
# 12574             Food
# Name: Category, Length: 12575, dtype: object

# %%
df["Category"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Item"]
# Out:
# 0         Item_10_PAT
# 1        Item_17_MILK
# 2         Item_12_BUT
# 3         Item_16_BEV
# 4         Item_6_FOOD
#              ...
# 12570     Item_23_PAT
# 12571      Item_2_BEV
# 12572      Item_7_BUT
# 12573      Item_7_FUR
# 12574     Item_9_FOOD
# Name: Item, Length: 12575, dtype: object

# %%
df["Item"].isnull().sum()
# Out:
# np.int64(1213)

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df=df.dropna(subset=["Item"])

# %%
df["Item"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Price Per Unit"]
# Out:
# 0        18.5
# 1        29.0
# 2        21.5
# 3        27.5
# 4        12.5
#          ...
# 12570    38.0
# 12571     6.5
# 12572    14.0
# 12573    14.0
# 12574    17.0
# Name: Price Per Unit, Length: 11362, dtype: float64

# %%
df["Price Per Unit"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Quantity"]
# Out:
# 0        10.0
# 1         9.0
# 2         2.0
# 3         9.0
# 4         7.0
#          ...
# 12570     4.0
# 12571     9.0
# 12572    10.0
# 12573     6.0
# 12574     3.0
# Name: Quantity, Length: 11362, dtype: float64

# %%
df["Quantity"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Total Spent"]
# Out:
# 0        185.0
# 1        261.0
# 2         43.0
# 3        247.5
# 4         87.5
#          ...
# 12570    152.0
# 12571     58.5
# 12572    140.0
# 12573     84.0
# 12574     51.0
# Name: Total Spent, Length: 11362, dtype: float64

# %%
df["Total Spent"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Payment Method"]
# Out:
# 0        Digital Wallet
# 1        Digital Wallet
# 2           Credit Card
# 3           Credit Card
# 4        Digital Wallet
#               ...
# 12570       Credit Card
# 12571              Cash
# 12572              Cash
# 12573              Cash
# 12574              Cash
# Name: Payment Method, Length: 11362, dtype: object

# %%
df["Payment Method"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Transaction Date"]
# Out:
# 0       2024-04-08
# 1       2023-07-23
# 2       2022-10-05
# 3       2022-05-07
# 4       2022-10-02
#            ...
# 12570   2023-09-03
# 12571   2022-08-12
# 12572   2024-08-24
# 12573   2023-12-30
# 12574   2022-08-06
# Name: Transaction Date, Length: 11362, dtype: datetime64[ns]

# %%
df["Transaction Date"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Discount Applied"]
# Out:
# 0        1.0
# 1        1.0
# 2        0.0
# 3        NaN
# 4        0.0
#         ...
# 12570    NaN
# 12571    0.0
# 12572    NaN
# 12573    1.0
# 12574    NaN
# Name: Discount Applied, Length: 11362, dtype: float64

# %%
df["Discount Applied"].isnull().sum()
# Out:
# np.int64(3783)

# %%
df[pd.to_numeric(df["Discount Applied"], errors="coerce").isnull()]
# Out:
#       Transaction ID                       Category          Item  \
# 3        TXN_9458126                      Beverages   Item_16_BEV
# 14       TXN_2490363                  Milk Products  Item_16_MILK
# 20       TXN_9939063                      Beverages    Item_7_BEV
# 22       TXN_6547964  Electric household essentials    Item_4_EHE
# 33       TXN_1494700  Electric household essentials   Item_21_EHE
# ...              ...                            ...           ...
# 12551    TXN_3673685                      Beverages   Item_12_BEV
# 12568    TXN_1096134                           Food   Item_4_FOOD
# 12570    TXN_9347481                     Patisserie   Item_23_PAT
# 12572    TXN_5306010                       Butchers    Item_7_BUT
# 12574    TXN_2407494                           Food   Item_9_FOOD
#
#        Price Per Unit  Quantity  Total Spent  Payment Method Transaction Date  \
# 3                27.5       9.0        247.5     Credit Card       2022-05-07
# ...

# %%
df["Discount Applied"] = pd.to_numeric(df["Discount Applied"], errors="coerce")

# %%
invalid_discounts = df[(df["Discount Applied"] < 0) | (df["Discount Applied"] > 100)]

# %%
df = df[(df["Discount Applied"] >= 0) & (df["Discount Applied"] <= 100)]

# %%
df["Discount Applied"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Total Revenue"] = df["Quantity"] * df["Price Per Unit"]

# %%
df.head()
# Out:
#   Transaction ID       Category          Item  Price Per Unit  Quantity  \
# 0    TXN_6867343     Patisserie   Item_10_PAT            18.5      10.0
# 1    TXN_3731986  Milk Products  Item_17_MILK            29.0       9.0
# 2    TXN_9303719       Butchers   Item_12_BUT            21.5       2.0
# 4    TXN_4575373           Food   Item_6_FOOD            12.5       7.0
# 6    TXN_3652209           Food   Item_1_FOOD             5.0       8.0
#
#    Total Spent  Payment Method Transaction Date  Discount Applied  \
# 0        185.0  Digital Wallet       2024-04-08               1.0
# 1        261.0  Digital Wallet       2023-07-23               1.0
# 2         43.0     Credit Card       2022-10-05               0.0
# 4         87.5  Digital Wallet       2022-10-02               0.0
# 6         40.0     Credit Card       2023-06-10               1.0
#
#    Total Revenue
# 0          185.0
# 1          261.0
# 2           43.0
# 4           87.5
# 6           40.0

# %%
df.drop("Payment Method", axis=1, inplace=True)

# %%
df
# Out:
#       Transaction ID       Category          Item  Price Per Unit  Quantity  \
# 0        TXN_6867343     Patisserie   Item_10_PAT            18.5      10.0
# 1        TXN_3731986  Milk Products  Item_17_MILK            29.0       9.0
# 2        TXN_9303719       Butchers   Item_12_BUT            21.5       2.0
# 4        TXN_4575373           Food   Item_6_FOOD            12.5       7.0
# 6        TXN_3652209           Food   Item_1_FOOD             5.0       8.0
# ...              ...            ...           ...             ...       ...
# 12566    TXN_6298574  Milk Products   Item_1_MILK             5.0       4.0
# 12567    TXN_4890318       Butchers    Item_3_BUT             8.0       5.0
# 12569    TXN_2318174     Patisserie    Item_1_PAT             5.0       9.0
# 12571    TXN_4009414      Beverages    Item_2_BEV             6.5       9.0
# 12573    TXN_5167298      Furniture    Item_7_FUR            14.0       6.0
#
# ...

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Category', 'Item', 'Price Per Unit', 'Quantity',
#        'Total Spent', 'Transaction Date', 'Discount Applied', 'Total Revenue'],
#       dtype='object')

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7579 entries, 0 to 12573
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    7579 non-null   object
#  1   Category          7579 non-null   object
#  2   Item              7579 non-null   object
#  3   Price Per Unit    7579 non-null   float64
#  4   Quantity          7579 non-null   float64
#  5   Total Spent       7579 non-null   float64
#  6   Transaction Date  7579 non-null   datetime64[ns]
#  7   Discount Applied  7579 non-null   float64
#  8   Total Revenue     7579 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(3)
# memory usage: 592.1+ KB
#        Price Per Unit     Quantity  Total Spent  \
# count     7579.000000  7579.000000  7579.000000
# mean        23.428882     5.557329   130.427893
# min          5.000000     1.000000     5.000000
# 25%         14.000000     3.000000    52.000000
# ...

# %%
df["Location"] = "Hyderabad"

# %%
import numpy as np

df["Location"] = np.random.choice(
    ["Hyderabad", "Chennai", "Mumbai", "Bangalore"],
    len(df)
)

# %%
df["Location"].value_counts()
# Out:
# Location
# Bangalore    1933
# Chennai      1920
# Hyderabad    1894
# Mumbai       1832
# Name: count, dtype: int64

# %%
df["Location"].value_counts()
# Out:
# Location
# Bangalore    1933
# Chennai      1920
# Hyderabad    1894
# Mumbai       1832
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Category', 'Item', 'Price Per Unit', 'Quantity',
#        'Total Spent', 'Transaction Date', 'Discount Applied', 'Total Revenue',
#        'Location'],
#       dtype='object')

# %%
import numpy as np

df["Payment Method"] = np.random.choice(
    ["Cash", "Card", "UPI", "Net Banking"],
    len(df)
)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Category', 'Item', 'Price Per Unit', 'Quantity',
#        'Total Spent', 'Transaction Date', 'Discount Applied', 'Total Revenue',
#        'Location', 'Payment Method'],
#       dtype='object')

# %%
df["Payment Method"].value_counts()
# Out:
# Payment Method
# UPI            1945
# Card           1935
# Net Banking    1871
# Cash           1828
# Name: count, dtype: int64

# %%
df.to_csv("cleaned_sales_data.csv", index=False)

# %% [markdown]
# df
